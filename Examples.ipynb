# %%
# %matplotlib inline
import numpy as np
import pymc3 as pm
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
data = np.random.randn(100)
with pm.Model() as model:
        mu = pm.Normal('mu', mu=0, sd=1, testval=0)
        sd = pm.HalfNormal('sd', sd=1)
        n = pm.Normal('n', mu=mu, sd=sd, observed=data)
        
        trace = pm.sample(5000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi...
# Average ELBO = -146.41: 100%|██████████| 200000/200000 [00:12<00:00, 16232.86it/s]
# Finished [100%]: Average ELBO = -146.4
# 100%|██████████| 5000/5000 [00:03<00:00, 1551.22it/s]

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf3fbe6ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf500976d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf4262c690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf500c8150>]], dtype=object)
